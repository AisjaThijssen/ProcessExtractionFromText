# %% [markdown]
# ### Cretae Flowchart from ChatGPT output
# This document is used to create a flowchart from the ChatGPT correct flowchart prompt output.
#
# Simply replace the new_event_list and process_flow with the ChatGPT output to create a new flowchart.

# %%
# The event descriptions corrected by ChatGPT
new_event_list = [
    {
        "original_event_id": 0,
        "event_description": "Het onderzoek van de zaak door de rechter vindt zo spoedig mogelijk plaats, maar altijd binnen twee maanden na ontvangst van de vordering of conclusie van het openbaar ministerie.",
    },
    {
        "original_event_id": 1,
        "event_description": "Voor de beslissingen bedoeld in artikel 6:6:10, eerste lid, onderdelen d, e en f, en derde lid, vindt het onderzoek door de rechter plaats binnen een maand na ontvangst van de vordering.",
    },
    {
        "original_event_id": 2,
        "event_description": "Het is de ter beschikking gestelde niet toegestaan om geneeskundige en psychologische rapporten persoonlijk in te zien.",
    },
    {
        "original_event_id": 3,
        "event_description": "De rechter kan, indien hij ernstig gevaar voor de geestelijke gezondheid van de ter beschikking gestelde vreest, bepalen dat inzage in geneeskundige en psychologische rapporten niet is toegestaan.",
    },
    {
        "original_event_id": 4,
        "event_description": "De rechter kan bepalen dat een reclasseringsmedewerker, arts, advocaat, of iemand die bijzondere toestemming heeft, de rapporten mag inzien.",
    },
    {
        "original_event_id": 5,
        "event_description": "Iemand die van de rechter bijzondere toestemming heeft verkregen, mag de rapporten inzien.",
    },
    {
        "original_event_id": 6,
        "event_description": "De ter beschikking gestelde kan een reclasseringsmedewerker machtigen om de rapporten in te zien.",
    },
    {
        "original_event_id": 7,
        "event_description": "De ter beschikking gestelde kan een arts machtigen om de rapporten in te zien.",
    },
    {
        "original_event_id": 8,
        "event_description": "De ter beschikking gestelde kan een advocaat machtigen om de rapporten in te zien.",
    },
    {
        "original_event_id": 9,
        "event_description": "De rechter hoort de ter beschikking gestelde en zijn raadsman alvorens te beslissen.",
    },
    {
        "original_event_id": 10,
        "event_description": "De griffier hoort de ter beschikking gestelde op zijn verblijfplaats.",
    },
    {
        "original_event_id": 11,
        "event_description": "Een van de rechters, vergezeld door de griffier, hoort de ter beschikking gestelde op zijn verblijfplaats.",
    },
    {
        "original_event_id": 12,
        "event_description": "Indien de ter beschikking gestelde zich in een ander arrondissement bevindt, kan de rechter het gehoor overdragen aan een rechter in dat arrondissement.",
    },
    {
        "original_event_id": 13,
        "event_description": "Indien zich na de indiening van de vordering een omstandigheid heeft voorgedaan, waardoor niet aan de hoorplicht kan worden voldaan.",
    },
    {
        "original_event_id": 14,
        "event_description": "De rechter beslist binnen twee maanden na het wegvallen van het beletsel om aan de hoorplicht te voldoen.",
    },
    {
        "original_event_id": 15,
        "event_description": "Beslissing op de vordering wordt genomen binnen twee maanden nadat het beletsel om aan de hoorplicht te voldoen, is weggevallen.",
    },
    {
        "original_event_id": 16,
        "event_description": "De rechter overweegt de voorwaarden waaronder de terugkeer van de ter beschikking gestelde in het maatschappelijk verkeer zou kunnen geschieden.",
    },
    {
        "original_event_id": 17,
        "event_description": "De rechter overweegt de voorwaardelijke beëindiging van de verpleging bij de verlenging van de terbeschikkingstelling.",
    },
    {
        "original_event_id": 18,
        "event_description": "Indien nodig, kan de rechter zich nader laten voorlichten over de voorwaardelijke beëindiging van de verpleging.",
    },
    {
        "original_event_id": 19,
        "event_description": "De rechter acht nader voorlichten noodzakelijk voor de beslissing over voorwaardelijke beëindiging van de verpleging.",
    },
    {
        "original_event_id": 20,
        "event_description": "De rechter overweegt de toepassing van artikel 2.3 van de Wet forensische zorg en kan, indien nodig, nader voorlichten aanvragen of de beslissing uitstellen.",
    },
    {
        "original_event_id": 21,
        "event_description": "De rechter kan zich nader laten voorlichten over de toepassing van artikel 2.3 van de Wet forensische zorg.",
    },
    {
        "original_event_id": 22,
        "event_description": "De rechter kan zijn beslissing voor ten hoogste drie maanden aanhouden bij het overwegen van de toepassing van artikel 2.3 van de Wet forensische zorg.",
    },
    {
        "original_event_id": 23,
        "event_description": "De rechter acht nader voorlichten noodzakelijk voor de toepassing van artikel 2.3 van de Wet forensische zorg.",
    },
    {
        "original_event_id": 24,
        "event_description": "De rechter kan zijn beslissing voor ten hoogste drie maanden aanhouden indien hij zich nader wil laten voorlichten over de terugkeer van de ter beschikking gestelde in het maatschappelijk verkeer.",
    },
    {
        "original_event_id": 25,
        "event_description": "De rechter overweegt de voorwaarden waaronder de terugkeer van de ter beschikking gestelde in het maatschappelijk verkeer zou kunnen geschieden. (2)",
    },
]

# %%
from graphviz import Digraph

# The Flow generated by ChatGPT
process_flow = [
    {
        "from_event": "start",
        "to_event": "De hulpofficier van justitie bij de voorgeleiding beveelt",
    },
    {
        "from_event": "De hulpofficier van justitie bij de voorgeleiding beveelt",
        "to_event": "De verdachte wordt opgehouden voor onderzoek",
    },
    {
        "from_event": "De verdachte wordt opgehouden voor onderzoek",
        "to_event": "In afwijking van artikel 27e, eerste lid, geeft de hulpofficier van justitie zo spoedig mogelijk kennis van de vrijheidsbeneming en van de redenen daarvan aan de ouders of voogd.",
    },
    {
        "from_event": "In afwijking van artikel 27e, eerste lid, geeft de hulpofficier van justitie zo spoedig mogelijk kennis van de vrijheidsbeneming en van de redenen daarvan aan de ouders of voogd.",
        "to_event": "of 0",
    },
    {
        "from_event": "of 0",
        "to_event": "De ouders ontvangen daarbij zo spoedig mogelijk een mededeling van rechten zoals bedoeld in artikel 488aa.",
    },
    {
        "from_event": "of 0",
        "to_event": "De voogd ontvangt daarbij zo spoedig mogelijk een mededeling van rechten zoals bedoeld in artikel 488aa.",
    },
    {
        "from_event": "De ouders ontvangen daarbij zo spoedig mogelijk een mededeling van rechten zoals bedoeld in artikel 488aa.",
        "to_event": "join 1",
    },
    {
        "from_event": "De voogd ontvangt daarbij zo spoedig mogelijk een mededeling van rechten zoals bedoeld in artikel 488aa.",
        "to_event": "join 1",
    },
    {
        "from_event": "join 1",
        "to_event": "De mededeling van rechten blijft achterwege onder de omstandigheden gespecificeerd in lid 2.",
    },
    {
        "from_event": "De mededeling van rechten blijft achterwege onder de omstandigheden gespecificeerd in lid 2.",
        "to_event": "of 2",
    },
    {
        "from_event": "of 2",
        "to_event": "De mededeling van rechten is in strijd met de belangen van de verdachte.",
    },
    {
        "from_event": "of 2",
        "to_event": "De ouders kunnen na redelijke inspanning niet worden bereikt voor de mededeling van rechten.",
    },
    {
        "from_event": "of 2",
        "to_event": "De voogd kan na redelijke inspanning niet worden bereikt voor de mededeling van rechten.",
    },
    {
        "from_event": "of 2",
        "to_event": "De ouders zijn onbekend waardoor de mededeling van rechten niet gedaan kan worden.",
    },
    {
        "from_event": "of 2",
        "to_event": "De voogd is onbekend waardoor de mededeling van rechten niet gedaan kan worden.",
    },
    {
        "from_event": "De ouders kunnen na redelijke inspanning niet worden bereikt voor de mededeling van rechten.",
        "to_event": "join 3",
    },
    {
        "from_event": "De voogd kan na redelijke inspanning niet worden bereikt voor de mededeling van rechten.",
        "to_event": "join 3",
    },
    {
        "from_event": "De ouders zijn onbekend waardoor de mededeling van rechten niet gedaan kan worden.",
        "to_event": "join 3",
    },
    {
        "from_event": "De voogd is onbekend waardoor de mededeling van rechten niet gedaan kan worden.",
        "to_event": "join 3",
    },
    {
        "from_event": "join 3",
        "to_event": "Het doen van de mededeling is niet mogelijk onder de gespecificeerde omstandigheden.",
    },
    {
        "from_event": "Het doen van de mededeling is niet mogelijk onder de gespecificeerde omstandigheden.",
        "to_event": "Indien de ouders of voogd niet bereikt kunnen worden, wordt de mededeling gedaan aan een vertrouwenspersoon.",
    },
    {
        "from_event": "Indien de ouders of voogd niet bereikt kunnen worden, wordt de mededeling gedaan aan een vertrouwenspersoon.",
        "to_event": "Als de verdachte geen vertrouwenspersoon heeft aangewezen, wordt de mededeling gedaan aan de raad voor de kinderbescherming.",
    },
    {
        "from_event": "Als de verdachte geen vertrouwenspersoon heeft aangewezen, wordt de mededeling gedaan aan de raad voor de kinderbescherming.",
        "to_event": "Als de verdachte geen vertrouwenspersoon heeft aangewezen en de ouders of voogd niet bereikt kunnen worden, wordt de mededeling gedaan aan de raad voor de kinderbescherming.",
    },
    {
        "from_event": "Als de verdachte geen vertrouwenspersoon heeft aangewezen en de ouders of voogd niet bereikt kunnen worden, wordt de mededeling gedaan aan de raad voor de kinderbescherming.",
        "to_event": "Indien de omstandigheden, bedoeld in het tweede lid, ophouden te bestaan, ontvangen de ouders de mededeling alsnog.",
    },
    {
        "from_event": "Indien de omstandigheden, bedoeld in het tweede lid, ophouden te bestaan, ontvangen de ouders de mededeling alsnog.",
        "to_event": "De voogd ontvangt de mededeling alsnog indien de omstandigheden veranderen.",
    },
    {
        "from_event": "De voogd ontvangt de mededeling alsnog indien de omstandigheden veranderen.",
        "to_event": "Indien de eerder belemmerende omstandigheden ophouden te bestaan, ontvangen de ouders de mededeling alsnog.",
    },
    {
        "from_event": "Indien de eerder belemmerende omstandigheden ophouden te bestaan, ontvangen de ouders de mededeling alsnog.",
        "to_event": "end",
    },
]


# Create a Digraph object
dot = Digraph()

# Add nodes and edges to the graph
for flow in process_flow:
    # In come cases ChatGPT returns the event id from the event list instead of the event description as Event {id} therefore these lines of code were created.
    from_event = [event for event in new_event_list if event["original_event_id"] == int(flow["from_event"].split(" ")[1])][0]["event_description"].replace(":", ",") if "Event" in flow["from_event"] else flow["from_event"]
    to_event = (
        [
            event
            for event in new_event_list
            if event["original_event_id"] == int(flow["to_event"].split(" ")[1])
        ][0]["event_description"].replace(":", ",")
        if "Event" in flow["to_event"]
        else flow["to_event"]
    )
    dot.node(from_event)
    dot.node(to_event)
    dot.edge(from_event, to_event)

# Render and display the graph
dot.render("process_model", format="png", cleanup=True)
# Out:
# 'process_model.png'
